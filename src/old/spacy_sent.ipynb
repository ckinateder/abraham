# %%
from news import NewsParser

import matplotlib.pyplot as plt
from pprint import pprint
from tqdm import tqdm
import spacy, os, random
import pandas as pd
from textblob import TextBlob
from textblob.classifiers import NaiveBayesClassifier

fsize = (16, 9)
dpi = 120
plt.rcParams.update({"figure.figsize": fsize, "figure.dpi": dpi}) # set params

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def breakdown_text(sentence):
    """
    Breakdown a sentence into the aspects and description
    """
    doc = nlp(sentence)
    descriptive_term = ''
    target = ''
    for token in doc:
        if token.dep_ == 'nsubj' and token.pos_ == 'NOUN':
            target = token.text
        if token.pos_ == 'ADJ':
            prepend = ''
            for child in token.children:
                if child.pos_ != 'ADV':
                    continue
                prepend += child.text + ' '
            descriptive_term = prepend + token.text
    return {'sentence': sentence,
            'aspect': target,
            'description': descriptive_term,
            'sentence_sentiment': TextBlob(sentence).sentiment,
            'desc_sentiment': TextBlob(descriptive_term).sentiment
           }

# %%
def analyze_sentences(sentences):
    """
    Analyze a list of sentences
    """
    aspects = []
    for sentence in sentences:
        breakdown=breakdown_text(sentence)
        aspects.append(breakdown)
    return aspects

# %%
sentences = [
  'Sales in Finland decreased by 10.5 % in January , while sales outside Finland dropped by 17 ',
  'My time in Italy was very enjoyable',
  'I found the meal to be tasty',
  'The internet was slow.',
  'Our experience was suboptimal'
]

# %%
analyze_sentences(sentences)
# Out:
# [{'sentence': 'Sales in Finland decreased by 10.5 % in January , while sales outside Finland dropped by 17 ',
#   'aspect': 'sales',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=-0.2, subjectivity=0.375),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'My time in Italy was very enjoyable',
#   'aspect': 'time',
#   'description': 'very enjoyable',
#   'sentence_sentiment': Sentiment(polarity=0.65, subjectivity=0.78),
#   'desc_sentiment': Sentiment(polarity=0.65, subjectivity=0.78)},
#  {'sentence': 'I found the meal to be tasty',
#   'aspect': 'meal',
#   'description': 'tasty',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'The internet was slow.',
#   'aspect': 'internet',
#   'description': 'slow',
#   'sentence_sentiment': Sentiment(polarity=-0.30000000000000004, subjectivity=0.39999999999999997),
#   'desc_sentiment': Sentiment(polarity=-0.30000000000000004, subjectivity=0.39999999999999997)},
#  {'sentence': 'Our experience was suboptimal',
#   'aspect': 'experience',
#   'description': 'suboptimal',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)}]

# %%
newsparser = NewsParser()
test_text_list = newsparser.get_articles("APPLE")
# Out:
# Failed on news.google.com/.?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/.?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/.?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/.?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/.?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/./articles/CAIiEDSit4z_7A1N3mfmzun8yowqFQgEKg0IACoGCAowrqkBMKBFMMGBAg?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/.?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/./articles/CAIiEC9z6SfM6NK_ugCLM1L-8I4qGQgEKhAIACoHCAownqWBCzD44fwCMMymtwY?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/./articles/CAIiEM_Zd-OJVhXKvFukE6oYpdEqGQgEKhAIACoHCAownqWBCzD44fwCMMymtwY?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/./articles/CAIiEP-ZPYnFi2u_Sh49UzGTb5AqFggEKg0IACoGCAowkqEGMJBZMOniuwY?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/./articles/CBMiY2h0dHBzOi8vdGVjaHN0b3J5LmluL2hlcmVzLWhvdy10by1jaGVjay15b3VyLWFwcGxlLXBlbmNpbC1iYXR0ZXJ5LXNvLXlvdS1yZWFsaXplLXdoZW4tdG8tY2hhcmdlLWl0L9IBAA?hl=en-US&gl=US&ceid=US%3Aen
# Failed on news.google.com/./articles/CAIiEGdhZ3tSzi6jf33zkk1lckYqGQgEKhAIACoHCAownob-CjCUzPYCMNDg3AU?hl=en-US&gl=US&ceid=US%3Aen

# %%
titles = [t['title'] for t in test_text_list]
desc = [t['desc'] for t in test_text_list]
#text = [t['text'] for t in test_text_list]
analyze_sentences(titles)
# Out:
# [{'sentence': 'Why new Apple products might be harder to buy this year',
#   'aspect': 'products',
#   'description': 'harder',
#   'sentence_sentiment': Sentiment(polarity=0.018181818181818174, subjectivity=0.22727272727272727),
#   'desc_sentiment': Sentiment(polarity=-0.1, subjectivity=0.0)},
#  {'sentence': "Everything You Need to Know About Apple's Find My Network Accessory Program",
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "Apple's Find My network now offers new third-party finding experiences",
#   'aspect': 'network',
#   'description': 'third',
#   'sentence_sentiment': Sentiment(polarity=0.11818181818181818, subjectivity=0.22727272727272727),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "Apple's Worldwide Developers Conference is back in its all-online format",
#   'aspect': '',
#   'description': 'online',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'iOS 15: 10 features we expect, want, and hope to see',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "Will Tesla Be the Next Apple? Here's How Investors Can Play It.",
#   'aspect': 'Investors',
#   'description': 'Next',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple Breakfast: Spring event is cancelled',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "Apple's Find My app is going to get a lot more powerful when locating your iPhone and more",
#   'aspect': 'app',
#   'description': 'more',
#   'sentence_sentiment': Sentiment(polarity=0.43333333333333335, subjectivity=0.6666666666666666),
#   'desc_sentiment': Sentiment(polarity=0.5, subjectivity=0.5)},
#  {'sentence': "Apple's iOS 14.5 Is Imminent. What It Means for Your iPhone and Your Privacy",
#   'aspect': '',
#   'description': 'Imminent',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Check out this super-rare iPhone with a misprinted Apple logo',
#   'aspect': '',
#   'description': 'rare',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.3, subjectivity=0.9)},
#  {'sentence': 'Apple Capitulates To Senator Demands, Sends Exec To Hearing; AppsFlyer Claims Opt-In Rates Will Be High',
#   'aspect': 'Rates',
#   'description': 'High',
#   'sentence_sentiment': Sentiment(polarity=0.16, subjectivity=0.5399999999999999),
#   'desc_sentiment': Sentiment(polarity=0.16, subjectivity=0.5399999999999999)},
#  {'sentence': 'Apple Arcade expands its award-winning catalog to more than 180 games',
#   'aspect': '',
#   'description': 'more',
#   'sentence_sentiment': Sentiment(polarity=0.5, subjectivity=0.5),
#   'desc_sentiment': Sentiment(polarity=0.5, subjectivity=0.5)},
#  {'sentence': 'First-Quarter PC Sales Grew at Fastest Rate in 20 Years',
#   'aspect': '',
#   'description': 'First',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.25, subjectivity=0.3333333333333333)},
#  {'sentence': 'He believed Apple’s App Store was safe. Then a fake app stole his life savings in bitcoin.',
#   'aspect': 'app',
#   'description': 'fake',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.75),
#   'desc_sentiment': Sentiment(polarity=-0.5, subjectivity=1.0)},
#  {'sentence': "Michigan's apple industry is taking a hit. Here's why",
#   'aspect': 'industry',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Tesla rallies after Canaccord upgrades rating, says it is like Apple',
#   'aspect': 'rallies',
#   'description': 'Tesla',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Golden Apple recipient Brooke Hoffman engages students to make learning fun',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.3, subjectivity=0.35),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple powers ahead in new renewable energy solutions with over 110 suppliers',
#   'aspect': '',
#   'description': 'renewable',
#   'sentence_sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Xiaomi is reportedly working on new tablets with 11" 120 Hz screens and Snapdragon chipsets - comments',
#   'aspect': '',
#   'description': 'new',
#   'sentence_sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453),
#   'desc_sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)},
#  {'sentence': 'Swaarm Has An Alternative Method For Attribution On iOS 14 – Minus The IDFA',
#   'aspect': '',
#   'description': 'iOS',
#   'sentence_sentiment': Sentiment(polarity=-0.1, subjectivity=0.1),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Chauvin is a rotten apple in a decaying barrel',
#   'aspect': '',
#   'description': 'rotten',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Northwest apple exports are down as Eastern European growers crunch into US shipments',
#   'aspect': 'growers',
#   'description': 'European',
#   'sentence_sentiment': Sentiment(polarity=-0.07777777777777779, subjectivity=0.14444444444444446),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple expands free professional learning to help teachers champion creativity',
#   'aspect': '',
#   'description': 'professional',
#   'sentence_sentiment': Sentiment(polarity=0.25, subjectivity=0.45),
#   'desc_sentiment': Sentiment(polarity=0.1, subjectivity=0.1)},
#  {'sentence': 'Apple Maps now displays COVID-19 vaccination locations',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "The Future Of Mobile Advertising Is Privacy-First – It's Time To Get Onboard With Apple's SKAdNetwork",
#   'aspect': 'Future',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.125),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple agrees to testify before U.S. Senate on app store antitrust concerns',
#   'aspect': '',
#   'description': 'antitrust',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Perseverance, empathy are touchstones for Mesa six-grade teacher',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Making sense of the latest Apple rumors: What is releasing, and when?',
#   'aspect': '',
#   'description': 'latest',
#   'sentence_sentiment': Sentiment(polarity=0.5, subjectivity=0.9),
#   'desc_sentiment': Sentiment(polarity=0.5, subjectivity=0.9)},
#  {'sentence': 'Jazz apples partners with Dreamworks movie Spirit Untamed – Produce Blue Book',
#   'aspect': 'partners',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.1),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Poet laureate Amanda Gorman joins the “The Oprah Conversation” on March 26',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple’s patent reveals a new system for predicting when your iPhone will run out of battery',
#   'aspect': 'patent',
#   'description': 'new',
#   'sentence_sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453),
#   'desc_sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)},
#  {'sentence': 'Golden Apple recipient Jenna Mixer provides individualized approach to learning',
#   'aspect': '',
#   'description': 'individualized',
#   'sentence_sentiment': Sentiment(polarity=0.3, subjectivity=0.5),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Caria app helps debunk the myths of menopause',
#   'aspect': 'app',
#   'description': 'Caria',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Golden Apple Award recipients team up to keep virtual school fun',
#   'aspect': 'recipients',
#   'description': 'virtual',
#   'sentence_sentiment': Sentiment(polarity=0.3, subjectivity=0.35),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'After major Klimt restitution by France, another work still vexes Vienna',
#   'aspect': 'work',
#   'description': 'major',
#   'sentence_sentiment': Sentiment(polarity=0.0625, subjectivity=0.5),
#   'desc_sentiment': Sentiment(polarity=0.0625, subjectivity=0.5)},
#  {'sentence': 'Does Apple Cider Vinegar Break a Fast?',
#   'aspect': '',
#   'description': 'Fast',
#   'sentence_sentiment': Sentiment(polarity=0.2, subjectivity=0.6),
#   'desc_sentiment': Sentiment(polarity=0.2, subjectivity=0.6)},
#  {'sentence': "Tim Cook drops some hints on Apple's car plans, shares what he thinks of Elon Musk and Tesla",
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "The Macalope knows when Apple's spring event will be held",
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'One Apple platform in 2021: The year iPad and Mac begin to converge',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "Apple's privacy change is poised to increase the power of its App Store",
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple Event tipped for April 6 — but this leak is probably fake',
#   'aspect': 'leak',
#   'description': 'fake',
#   'sentence_sentiment': Sentiment(polarity=-0.5, subjectivity=1.0),
#   'desc_sentiment': Sentiment(polarity=-0.5, subjectivity=1.0)},
#  {'sentence': 'Apple Earnings Date: When Will The Company Report?',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "Apple's Siri will stop defaulting to a female voice in the U.S., two new voices coming",
#   'aspect': '',
#   'description': 'new',
#   'sentence_sentiment': Sentiment(polarity=0.06818181818181818, subjectivity=0.3106060606060606),
#   'desc_sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)},
#  {'sentence': "Cosmic Crisp and the 'feel-like' factor – Produce Blue Book",
#   'aspect': '',
#   'description': 'like',
#   'sentence_sentiment': Sentiment(polarity=0.125, subjectivity=0.25833333333333336),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'After Anti-M1 Ads, Intel Wants to Make Future Apple Silicon Chips',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.1, subjectivity=0.1125),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple releases emergency update for iPhones, iPads, and Apple Watch',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple Watch News: Rugged Model For Extreme Sports Under Consideration',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=-0.125, subjectivity=1.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Android sends 20x more data to Google than iOS sends to Apple, study says',
#   'aspect': 'study',
#   'description': 'iOS',
#   'sentence_sentiment': Sentiment(polarity=0.5, subjectivity=0.5),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple knew it was selling defective MacBook displays, judge concludes',
#   'aspect': '',
#   'description': 'defective',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'New Apple Leak Suggests Earlier iPhone 13 Release',
#   'aspect': '',
#   'description': 'Earlier',
#   'sentence_sentiment': Sentiment(polarity=0.06818181818181818, subjectivity=0.4772727272727273),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.5)},
#  {'sentence': 'Apple Wants iPhone 12 Owners to Keep Calm When Disaster Strikes',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.25, subjectivity=0.425),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple Is on Its Way to Becoming a Bigger Player in This Market',
#   'aspect': '',
#   'description': 'Bigger',
#   'sentence_sentiment': Sentiment(polarity=0.225, subjectivity=0.675),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.5)},
#  {'sentence': 'AAPL After Hours: Why Apple Stock Wobbled This Tuesday',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Why Is Facebook Suddenly Bullish on the Apple Privacy Update?',
#   'aspect': '',
#   'description': 'Suddenly Bullish',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.5),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.5)},
#  {'sentence': 'Apple, Epic Games CEOs on list of witnesses in Fortnite case',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.1, subjectivity=0.4),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple Told to Pay $308.5 Million for Infringing DRM Patent',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple picked a truly embarrassing time to wrongly reject a simple app update',
#   'aspect': '',
#   'description': 'simple',
#   'sentence_sentiment': Sentiment(polarity=-0.25, subjectivity=0.6285714285714286),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.35714285714285715)},
#  {'sentence': 'Apple discontinues original HomePod, will focus on mini',
#   'aspect': '',
#   'description': 'original',
#   'sentence_sentiment': Sentiment(polarity=0.375, subjectivity=0.75),
#   'desc_sentiment': Sentiment(polarity=0.375, subjectivity=0.75)},
#  {'sentence': 'Centralia to be beautified by apple trees, butterflies during planting event on April 17',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Golden Apple: South Kingstown paraprofessional is a great listener and motivator',
#   'aspect': 'paraprofessional',
#   'description': 'great',
#   'sentence_sentiment': Sentiment(polarity=0.55, subjectivity=0.625),
#   'desc_sentiment': Sentiment(polarity=0.8, subjectivity=0.75)},
#  {'sentence': 'Apple Bent the Rules for Russia—and Other Countries Will Take Note',
#   'aspect': 'Countries',
#   'description': 'Other',
#   'sentence_sentiment': Sentiment(polarity=-0.125, subjectivity=0.375),
#   'desc_sentiment': Sentiment(polarity=-0.125, subjectivity=0.375)},
#  {'sentence': 'Apple Watch Series 7 Release Date: When & How Much To Expect',
#   'aspect': '',
#   'description': 'When How Much',
#   'sentence_sentiment': Sentiment(polarity=0.2, subjectivity=0.2),
#   'desc_sentiment': Sentiment(polarity=0.2, subjectivity=0.2)},
#  {'sentence': 'Volofit opens fitness studio in Apple Valley | Free',
#   'aspect': 'Volofit',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.4, subjectivity=0.8),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'When Did Apple Watch SE Come Out & How Much Does It Cost?',
#   'aspect': '',
#   'description': 'How Much',
#   'sentence_sentiment': Sentiment(polarity=0.2, subjectivity=0.2),
#   'desc_sentiment': Sentiment(polarity=0.2, subjectivity=0.2)},
#  {'sentence': "Here's how to check your Apple Pencil battery so you realize when to charge it.",
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "Google, Apple top ranking of S'pore's best employers",
#   'aspect': '',
#   'description': 'best',
#   'sentence_sentiment': Sentiment(polarity=0.75, subjectivity=0.4),
#   'desc_sentiment': Sentiment(polarity=1.0, subjectivity=0.3)},
#  {'sentence': 'iPhone 13: More evidence for energy-efficient LTPO screens',
#   'aspect': '',
#   'description': 'efficient',
#   'sentence_sentiment': Sentiment(polarity=0.5, subjectivity=0.5),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'The Auto Sleuth: A Canoo lifestyle vehicle, an Apple car, an Ioniq 45 and more – Chilliwack Progress',
#   'aspect': '',
#   'description': 'more',
#   'sentence_sentiment': Sentiment(polarity=0.5, subjectivity=0.5),
#   'desc_sentiment': Sentiment(polarity=0.5, subjectivity=0.5)},
#  {'sentence': 'Batlow farmer reshapes his apple-growing future',
#   'aspect': 'farmer',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.125),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'iPhone 12 and iPhone 12 mini - Technical Specifications',
#   'aspect': '',
#   'description': 'Technical',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.1),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.1)},
#  {'sentence': 'Apple Events - October 2020',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple services entertain, inform, and connect the world in unprecedented year',
#   'aspect': 'services',
#   'description': 'unprecedented',
#   'sentence_sentiment': Sentiment(polarity=0.6, subjectivity=0.9),
#   'desc_sentiment': Sentiment(polarity=0.6, subjectivity=0.9)},
#  {'sentence': 'Apple Events - September 2020',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'When To Buy Apple',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'iOS 14 is available today apple.co',
#   'aspect': '',
#   'description': 'available',
#   'sentence_sentiment': Sentiment(polarity=0.4, subjectivity=0.4),
#   'desc_sentiment': Sentiment(polarity=0.4, subjectivity=0.4)},
#  {'sentence': 'iPhone 12 Pro Max, iPhone 12 mini, and HomePod mini available to order Friday',
#   'aspect': '',
#   'description': 'available',
#   'sentence_sentiment': Sentiment(polarity=0.4, subjectivity=0.4),
#   'desc_sentiment': Sentiment(polarity=0.4, subjectivity=0.4)},
#  {'sentence': 'When To Buy Apple Stock: The Best Strategy',
#   'aspect': '',
#   'description': 'Best',
#   'sentence_sentiment': Sentiment(polarity=1.0, subjectivity=0.3),
#   'desc_sentiment': Sentiment(polarity=1.0, subjectivity=0.3)},
#  {'sentence': 'Press Release: Apple announces Mac transition to Apple silicon',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple launches major new Racial Equity and Justice Initiative projects to challenge systemic racism, advance racial equity nationwide',
#   'aspect': '',
#   'description': 'racial',
#   'sentence_sentiment': Sentiment(polarity=0.09943181818181818, subjectivity=0.4772727272727273),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Lopez V. Apple: When An Alleged Injury Is Too Speculative To Confer Article III Standing - Consumer Protection - United States',
#   'aspect': '',
#   'description': 'Too Speculative',
#   'sentence_sentiment': Sentiment(polarity=-0.1, subjectivity=0.1),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "Here's How Much Investing $1000 In Apple When Trump Sold Would Be Worth Today",
#   'aspect': '',
#   'description': 'Worth',
#   'sentence_sentiment': Sentiment(polarity=0.25, subjectivity=0.15000000000000002),
#   'desc_sentiment': Sentiment(polarity=0.3, subjectivity=0.1)},
#  {'sentence': 'Apple announces App Store Small Business Program',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=-0.25, subjectivity=0.4),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': "Apple's Cork campus celebrates 40 years of community and looks to the future",
#   'aspect': 'campus',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.125),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Tesla approached Apple when it was most vulnerable, but it was ignored: Elon Musk',
#   'aspect': 'Tesla',
#   'description': 'most vulnerable',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.5),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.5)},
#  {'sentence': 'iPhone 12 and iPhone 12 mini',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Epic Games files lawsuit against Apple after Fortnite is removed from the App Store',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.1, subjectivity=0.4),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple M1 Chip',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple presents App Store Best of 2020 winners',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=1.0, subjectivity=0.3),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple Fitness+: The future of fitness launches December 14',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.125),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'sentence': 'Apple introduces macOS Big Sur with a beautiful new design',
#   'aspect': '',
#   'description': 'new',
#   'sentence_sentiment': Sentiment(polarity=0.3287878787878788, subjectivity=0.5181818181818182),
#   'desc_sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)},
#  {'sentence': 'Apple Hearing Study shares new insights on hearing health Apple• 3 hours ago',
#   'aspect': '',
#   'description': 'new',
#   'sentence_sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453),
#   'desc_sentiment': Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)},
#  {'sentence': 'Apple announces Apple Music radio',
#   'aspect': '',
#   'description': '',
#   'sentence_sentiment': Sentiment(polarity=0.0, subjectivity=0.0),
#   'desc_sentiment': Sentiment(polarity=0.0, subjectivity=0.0)}]

# %%
def load_tagged_set(fname):
    """
    Loaded a tagged csv file in format
    
    text | sentiment
    text | sentiment
    text | sentiment
    ...    
    text | sentiment
    """
    pre_set = pd.read_csv(fname)
    #doc = nlp(pre_set.iloc[0,0])
    return list(pre_set.to_records(index=False))

# %%
train = load_tagged_set('datasets/financial-headlines.csv')[:-80]
test = load_tagged_set('datasets/financial-headlines.csv')[-80:]

cl = NaiveBayesClassifier(train)
cl.show_informative_features(10)
